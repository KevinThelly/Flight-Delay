# %%
import pandas as pd
import json
import os
import pprint as pprint
import csv

# %%
os.chdir(r"C:\Users\Kevin Thelly\Downloads\ML")
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 - Basic data types.ipynb',
#  '01 - numPy Basics.ipynb',
#  '02 - pandas Basics.ipynb',
#  '2016',
#  '2017',
#  'Flight code.ipynb',
#  'flight16.csv',
#  'flight17.csv',
#  'Json Unwrapper.ipynb',
#  'merge_weather.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'WAIML2018_Expt5_linearRegression-checkpoint.ipynb',
#  'Weather',
#  'weather.csv',
#  'weather16.csv',
#  'weather17.csv']

# %%
#df=pd.read_csv(open('./2016/On_Time_On_Time_Performance_2016_1/On_Time_On_Time_Performance_2016_1.csv'),low_memory=False)
#flightdf=open('flightdata.csv') 
fields=['FlightDate','Quarter','Year','Month','DayofMonth','DepTime','DepDel15','CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']

# %%
flight2016=[]
for i in os.listdir():
    if('2016' in i):
        for j in os.listdir('./'+i):
            for k in os.listdir('./' +i+'/'+j):
                if('readme' not in k):
                    df=pd.read_csv(open('./'+i+'./' +j+'/'+k))
                    temp=pd.DataFrame(df,columns=['FlightDate','Quarter','Year','Month','DayofMonth','DepTime','DepDel15','CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes','Origin','Dest'])
                    flight2016.append(temp.loc[df['Origin'].isin(['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO']) & df['Dest'].isin(['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO'])])
                    print(k)
# Out:
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# On_Time_On_Time_Performance_2016_1.csv
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# On_Time_On_Time_Performance_2016_10.csv
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (48,69,76,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
flight2016df=pd.concat(flight2016,axis=0,)

# %%
flight2016df.to_csv('flight16.csv')

# %%
flight2016df.shape
# Out:
# (948819, 17)

# %%
flight2017=[]
for i in os.listdir():
    if('2017' in i):
        for j in os.listdir('./'+i):
            for k in os.listdir('./' +i+'/'+j):
                if('readme' not in k):
                    df=pd.read_csv(open('./'+i+'/' +j+'/'+k))
                    temp=pd.DataFrame(df,columns=['FlightDate','Quarter','Year','Month','DayofMonth','DepTime','DepDel15','CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes','Origin','Dest'])
                    flight2017.append(temp.loc[df['Origin'].isin(['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO']) & df['Dest'].isin(['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO'])])
                    print(k)
# Out:
# On_Time_On_Time_Performance_2017_1.csv
# On_Time_On_Time_Performance_2017_10.csv
# On_Time_On_Time_Performance_2017_11.csv
# On_Time_On_Time_Performance_2017_12.csv
# On_Time_On_Time_Performance_2017_2.csv
# On_Time_On_Time_Performance_2017_3.csv
# On_Time_On_Time_Performance_2017_4.csv
# On_Time_On_Time_Performance_2017_5.csv
# On_Time_On_Time_Performance_2017_6.csv
# On_Time_On_Time_Performance_2017_7.csv
# On_Time_On_Time_Performance_2017_8.csv
# On_Time_On_Time_Performance_2017_9.csv

# %%
flight2017df=pd.concat(flight2017,axis=0)

# %%
flight2017df.to_csv('flight17.csv')

# %%
flight2017df.shape
# Out:
# (928477, 17)

# %%
flight12=[]
#os.listdir('./2016/On_Time_On_Time_Performance_2016_1')
dp=pd.read_csv(open(r'./2016/On_Time_On_Time_Performance_2016_1/On_Time_On_Time_Performance_2016_1.csv'))
flight123=pd.DataFrame(dp,columns=['Origin','Quarter'])

flight123
# Out:
#        Origin  Quarter
# 0         DFW        1
# 1         DFW        1
# 2         DFW        1
# 3         DFW        1
# 4         DFW        1
# 5         DFW        1
# 6         DFW        1
# 7         DFW        1
# 8         DFW        1
# 9         DFW        1
# 10        DFW        1
# 11        DFW        1
# 12        DFW        1
# 13        DFW        1
# 14        DFW        1
# 15        DFW        1
# 16        DFW        1
# 17        DFW        1
# 18        DFW        1
# 19        DFW        1
# 20        DFW        1
# 21        DFW        1
# 22        DFW        1
# 23        DFW        1
# 24        DFW        1
# 25        DFW        1
# 26        DTW        1
# 27        DTW        1
# 28        DTW        1
# 29        DTW        1
# ...       ...      ...
# 445797    ATL        1
# 445798    CLE        1
# 445799    TPA        1
# 445800    CLE        1
# 445801    ATL        1
# 445802    MIA        1
# 445803    ORD        1
# 445804    MCO        1
# ...

# %%
flight2016df.drop_duplicates().shape
# Out:
# (948810, 17)

# %%
tempdata=flightdata.loc[df['Origin'].isin(['ATL','CLT']) | df['Dest'].isin(['ATL','CLT'])]

# %%
tempdata[['Origin','Dest']]
# Out:
#        Origin Dest
# 29        BOS  ATL
# 38        CLT  JFK
# 39        JFK  CLT
# 100       BOS  CLT
# 101       CLT  BOS
# 161       BOS  CLT
# 162       CLT  BOS
# 450       CLT  JFK
# 451       JFK  CLT
# 524       ATL  BOS
# 525       BOS  ATL
# 531       ATL  BOS
# 668       ATL  BOS
# 669       BOS  ATL
# 706       ATL  BOS
# 707       BOS  ATL
# 780       ATL  BOS
# 781       BOS  ATL
# 817       BOS  ATL
# 882       BOS  CLT
# 883       CLT  BOS
# 943       BOS  CLT
# 944       CLT  BOS
# 1219      CLT  JFK
# 1220      JFK  CLT
# 1290      ATL  BOS
# 1291      BOS  ATL
# 1297      ATL  BOS
# 1435      ATL  BOS
# 1436      BOS  ATL
# ...       ...  ...
# 457218    CLT  BOS
# 457543    CLT  JFK
# 457544    JFK  CLT
# 457616    ATL  BOS
# 457617    BOS  ATL
# 457623    ATL  BOS
# 457772    ATL  BOS
# 457773    BOS  ATL
# 457811    ATL  BOS
# 457812    BOS  ATL
# 457892    ATL  BOS
# 457893    BOS  ATL
# 457932    BOS  ATL
# 457941    CLT  JFK
# 457942    JFK  CLT
# ...

# %%
# fields=['FlightDate','Quarter','Year','Month','DayofMonth','DepTime','DepDel15','CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']

# with open('flightdata.csv','a') as flightdf:
#     csvwriter=csv.writer(flightdf)
#     csvwriter.writerow(fields)
#     csvwriter.writerows(df[fields].values)

# %%
# with open('flightdata.csv','a') as flightdf:
#     csvwriter=csv.writer(flightdf)
#     csvwriter.writerow(fields)
#     for i in os.listdir():
#         if('2016' in i):
#             for j in os.listdir('./'+i):
#                 for k in os.listdir('./' +i+'/'+j):
#                     if('readme' not in k):
#                         df=pd.read_csv(open('./'+i+'./' +j+'/'+k))
#                         csvwriter.writerows(df[fields].values)
#                         print(k)
# Out:
# array([['2017-05-15', 2],
#        ['2017-05-15', 2],
#        ['2017-05-15', 2],
#        ...,
#        ['2017-05-06', 2],
#        ['2017-05-06', 2],
#        ['2017-05-06', 2]], dtype=object)
