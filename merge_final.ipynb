# %%
import pandas as pd
import os

# %%
f16=pd.read_csv(open('flight16.csv'))
f17=pd.read_csv(open('flight17.csv'))
w16=pd.read_csv(open('weather16.csv'))
w17=pd.read_csv(open('weather17.csv'))

# %%
f16=f16.dropna()
f16.shape
# Out:
# (936961, 18)

# %%
f17.FlightDate=pd.to_datetime(f17.FlightDate)

# %%
f17.shape
# Out:
# (928477, 18)

# %%
f17=f17.dropna()
f17.shape
# Out:
# (914475, 18)

# %%
f16.FlightDate=pd.to_datetime(f16.FlightDate)

# %%
f16.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# dtype: object

# %%
f16['date']=f16['FlightDate']
f16['Arrtime1']=f16['CRSArrTime']
f16['Deptime1']=f16['CRSDepTime']
f16.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# date               datetime64[ns]
# Arrtime1                    int64
# Deptime1                    int64
# dtype: object

# %%
f17['date']=f17['FlightDate']
f17['Arrtime1']=f17['CRSArrTime']
f17['Deptime1']=f17['CRSDepTime']
f17.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# date               datetime64[ns]
# Arrtime1                    int64
# Deptime1                    int64
# dtype: object

# %%
w16.dtypes
# Out:
# Unnamed: 0         int64
# windspeedKmph      int64
# weatherCode        int64
# precipMM         float64
# WindGustKmph       int64
# pressure           int64
# cloudcover         int64
# winddirDegree      int64
# humidity           int64
# cloudcover.1       int64
# DewPointF          int64
# tempF              int64
# time               int64
# WindChillF         int64
# date              object
# place             object
# dtype: object

# %%
for index, row in f16.iterrows():
    temp=row['Arrtime1']%100
    temp1=row['Deptime1']%100
    something=row['Arrtime1']-temp
    something1=row['Deptime1']-temp1
    f16.at[index,'Arrtime1'] =something 
    f16.at[index,'Deptime1'] =something1 
    if(row['CRSArrTime']<row['CRSDepTime']):
        y = row['date']+ pd.DateOffset(days=1)
        f16.at[index,'date']=y

# %%
for index, row in f16.iterrows():
    if(row['CRSArrTime']==2400):
        f16.at[index,'CRSArrTime']=0
        print(row)
# Out:
# Unnamed: 0                      262918
# FlightDate         2016-06-01 00:00:00
# Quarter                              2
# Year                              2016
# Month                                6
# DayofMonth                           1
# DepTime                            109
# DepDel15                             1
# CRSDepTime                        2225
# DepDelayMinutes                    164
# OriginAirportID                  13930
# DestAirportID                    11292
# ArrTime                            235
# CRSArrTime                        2400
# ArrDel15                             1
# ArrDelayMinutes                    155
# Origin                             ORD
# Dest                               DEN
# date               2016-06-01 00:00:00
# Arrtime1                          2400
# Deptime1                          2225
# Name: 666006, dtype: object
# Unnamed: 0                      262919
# FlightDate         2016-06-02 00:00:00
# ...

# %%
f16['date']=f16['FlightDate']
f16['Arrtime1']=f16['CRSArrTime']
f16['Deptime1']=f16['CRSDepTime']
f16.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# date               datetime64[ns]
# Arrtime1                    int64
# Deptime1                    int64
# dtype: object

# %%
for index, row in f17.iterrows():
    if(row['CRSArrTime']==2400):
        f17.at[index,'CRSArrTime']=0
        print(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-783cf8cc50fe> in <module>
# ----> 1 for index, row in f17.iterrows():
#       2     if(row['CRSArrTime']==2400):
#       3         f17.at[index,'CRSArrTime']=0
#       4         print(row)
#
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     844         klass = self._constructor_sliced
#     845         for k, v in zip(self.index, self.values):
# --> 846             s = klass(v, index=columns, name=k)
#     847             yield k, s
#     848
#
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# ...

# %%
f17.loc[f17['CRSArrTime'].isin([2400])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FlightDate, Quarter, Year, Month, DayofMonth, DepTime, DepDel15, CRSDepTime, DepDelayMinutes, OriginAirportID, DestAirportID, ArrTime, CRSArrTime, ArrDel15, ArrDelayMinutes, Origin, Dest]
# Index: []

# %%
for index, row in f16.iterrows():
    temp=row['Arrtime1']%100
    temp1=row['Deptime1']%100
    something=row['Arrtime1']-temp
    something1=row['Deptime1']-temp1
    f16.at[index,'Arrtime1'] =something 
    f16.at[index,'Deptime1'] =something1 
    if(row['CRSArrTime']<row['CRSDepTime']):
        y = row['date']+ pd.DateOffset(days=1)
        f16.at[index,'date']=y

# %%
for index, row in f17.iterrows():
    temp=row['Arrtime1']%100
    temp1=row['Deptime1']%100
    something=row['Arrtime1']-temp
    something1=row['Deptime1']-temp1
    f17.at[index,'Arrtime1'] =something 
    f17.at[index,'Deptime1'] =something1 
    if(row['CRSArrTime']<row['CRSDepTime']):
        y = row['date']+ pd.DateOffset(days=1)
        f17.at[index,'date']=y

# %%
f16
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0               57 2016-01-01        1  2016      1           1    741.0
# 1               58 2016-01-02        1  2016      1           2    737.0
# 2               59 2016-01-03        1  2016      1           3    743.0
# 3               60 2016-01-04        1  2016      1           4    737.0
# 4               61 2016-01-05        1  2016      1           5    708.0
# 5               62 2016-01-06        1  2016      1           6    703.0
# 6               63 2016-01-07        1  2016      1           7    704.0
# 7               64 2016-01-08        1  2016      1           8    701.0
# 8               65 2016-01-09        1  2016      1           9    703.0
# 9               66 2016-01-10        1  2016      1          10    711.0
# 10              67 2016-01-11        1  2016      1          11    709.0
# 11              68 2016-01-12        1  2016      1          12    636.0
# ...

# %%
w17.date=pd.to_datetime(w17.date)
w17.dtypes
# Out:
# Unnamed: 0                int64
# windspeedKmph             int64
# weatherCode               int64
# precipMM                float64
# WindGustKmph              int64
# pressure                  int64
# cloudcover                int64
# winddirDegree             int64
# humidity                  int64
# cloudcover.1              int64
# DewPointF                 int64
# tempF                     int64
# time                      int64
# WindChillF                int64
# date             datetime64[ns]
# place                    object
# dtype: object

# %%
result17=pd.merge(f17,w17, left_on=['Origin','date','Deptime1'], right_on=['place','date','time'])

# %%
result17[['FlightDate','date','DepTime','Deptime1','ArrTime','Arrtime1','time']]
# Out:
#        FlightDate       date  DepTime  Deptime1  ArrTime  Arrtime1  time
# 0      2017-01-17 2017-01-17   1616.0      1500   1842.0      1800  1500
# 1      2017-01-17 2017-01-17   1637.0      1500   1813.0      1800  1500
# 2      2017-01-17 2017-01-17   1614.0      1500   1847.0      1800  1500
# 3      2017-01-17 2017-01-17   1618.0      1500   1823.0      1800  1500
# 4      2017-01-17 2017-01-17   1603.0      1500   1714.0      1700  1500
# 5      2017-01-17 2017-01-17   1626.0      1500   1831.0      1800  1500
# 6      2017-01-17 2017-01-17   1624.0      1500   1734.0      1700  1500
# 7      2017-01-17 2017-01-17   1550.0      1500   1701.0      1700  1500
# 8      2017-01-18 2017-01-18   1614.0      1500   1821.0      1800  1500
# 9      2017-01-18 2017-01-18   1638.0      1500   1833.0      1800  1500
# 10     2017-01-18 2017-01-18   1613.0      1500   1832.0      1800  1500
# 11     2017-01-18 2017-01-18   1620.0      1500   1714.0      1700  1500
# ...

# %%
result17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 914373 entries, 0 to 914372
# Data columns (total 36 columns):
# Unnamed: 0_x       914373 non-null int64
# FlightDate         914373 non-null datetime64[ns]
# Quarter            914373 non-null int64
# Year               914373 non-null int64
# Month              914373 non-null int64
# DayofMonth         914373 non-null int64
# DepTime            914373 non-null float64
# DepDel15           914373 non-null float64
# CRSDepTime         914373 non-null int64
# DepDelayMinutes    914373 non-null float64
# OriginAirportID    914373 non-null int64
# DestAirportID      914373 non-null int64
# ArrTime            914373 non-null float64
# CRSArrTime         914373 non-null int64
# ArrDel15           914373 non-null float64
# ArrDelayMinutes    914373 non-null float64
# Origin             914373 non-null object
# Dest               914373 non-null object
# date               914373 non-null datetime64[ns]
# ...

# %%
# w17=w17.rename(index=str,columns={"place":"Dest"})

# %%
# result17 = pd.merge(f17,w17,on=['Dest','date','time'])

# %%
result17.shape
# Out:
# (914373, 36)

# %%
f17.shape
# Out:
# (914475, 21)

# %%
result172=pd.merge(result17,w17, left_on=['Dest','date','Arrtime1'], right_on=['place','date','time'])

# %%
result172.shape
# Out:
# (914373, 51)

# %%
result172.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 914373 entries, 0 to 914372
# Data columns (total 51 columns):
# Unnamed: 0_x       914373 non-null int64
# FlightDate         914373 non-null datetime64[ns]
# Quarter            914373 non-null int64
# Year               914373 non-null int64
# Month              914373 non-null int64
# DayofMonth         914373 non-null int64
# DepTime            914373 non-null float64
# DepDel15           914373 non-null float64
# CRSDepTime         914373 non-null int64
# DepDelayMinutes    914373 non-null float64
# OriginAirportID    914373 non-null int64
# DestAirportID      914373 non-null int64
# ArrTime            914373 non-null float64
# CRSArrTime         914373 non-null int64
# ArrDel15           914373 non-null float64
# ArrDelayMinutes    914373 non-null float64
# Origin             914373 non-null object
# Dest               914373 non-null object
# date               914373 non-null datetime64[ns]
# ...

# %%
result172[['FlightDate','date','DepTime','Deptime1','ArrTime','Arrtime1','time']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-5b29fa5148e4> in <module>
# ----> 1 result172[['FlightDate','date','DepTime','Deptime1','ArrTime','Arrtime1','time']]
#
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
result123=result172.dropna()

# %%
result123.shape
# Out:
# (914373, 51)

# %%
result172.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 914373 entries, 0 to 914372
# Data columns (total 48 columns):
# Unnamed: 0_x       914373 non-null int64
# FlightDate         914373 non-null datetime64[ns]
# Quarter            914373 non-null int64
# Year               914373 non-null int64
# Month              914373 non-null int64
# DayofMonth         914373 non-null int64
# DepTime            914373 non-null float64
# DepDel15           914373 non-null float64
# CRSDepTime         914373 non-null int64
# DepDelayMinutes    914373 non-null float64
# OriginAirportID    914373 non-null int64
# DestAirportID      914373 non-null int64
# ArrTime            914373 non-null float64
# CRSArrTime         914373 non-null int64
# ArrDel15           914373 non-null float64
# ArrDelayMinutes    914373 non-null float64
# Origin             914373 non-null object
# Dest               914373 non-null object
# date               914373 non-null datetime64[ns]
# ...

# %%
result172.to_csv('result17.csv')

# %%
# for index, row in f16.iterrows():
#     temp=row['Arrhr']%100
#     something=row['Arrhr']-temp
#     f16.at[index,'Arrhr'] =something

# %%
w16.date=pd.to_datetime(w16.date)
w16.dtypes
# Out:
# Unnamed: 0                int64
# windspeedKmph             int64
# weatherCode               int64
# precipMM                float64
# WindGustKmph              int64
# pressure                  int64
# cloudcover                int64
# winddirDegree             int64
# humidity                  int64
# cloudcover.1              int64
# DewPointF                 int64
# tempF                     int64
# time                      int64
# WindChillF                int64
# date             datetime64[ns]
# place                    object
# dtype: object

# %%
f16[['FlightDate','ArrDate','DepTime','ArrTime','Arrhr']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-e7fdc30470b8> in <module>
# ----> 1 f16[['FlightDate','ArrDate','DepTime','ArrTime','Arrhr']]
#
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# c:\users\kevin thelly\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
# w16=w16.rename(index=str,columns={"place":"Dest"})

# %%
w16.dtypes
# Out:
# Unnamed: 0                int64
# windspeedKmph             int64
# weatherCode               int64
# precipMM                float64
# WindGustKmph              int64
# pressure                  int64
# cloudcover                int64
# winddirDegree             int64
# humidity                  int64
# cloudcover.1              int64
# DewPointF                 int64
# tempF                     int64
# time                      int64
# WindChillF                int64
# date             datetime64[ns]
# Dest                     object
# dtype: object

# %%
# result = pd.merge(f16,w16,on=['Dest','date','time'])

# %%
result=pd.merge(f16,w16, left_on=['Dest','date','Arrtime1'], right_on=['place','date','time'])

# %%
w16.dtypes
# Out:
# Unnamed: 0                int64
# windspeedKmph             int64
# weatherCode               int64
# precipMM                float64
# WindGustKmph              int64
# pressure                  int64
# cloudcover                int64
# winddirDegree             int64
# humidity                  int64
# cloudcover.1              int64
# DewPointF                 int64
# tempF                     int64
# time                      int64
# WindChillF                int64
# date             datetime64[ns]
# place                    object
# dtype: object

# %%
f16.dtypes
# Out:
# Unnamed: 0                  int64
# FlightDate         datetime64[ns]
# Quarter                     int64
# Year                        int64
# Month                       int64
# DayofMonth                  int64
# DepTime                   float64
# DepDel15                  float64
# CRSDepTime                  int64
# DepDelayMinutes           float64
# OriginAirportID             int64
# DestAirportID               int64
# ArrTime                   float64
# CRSArrTime                  int64
# ArrDel15                  float64
# ArrDelayMinutes           float64
# Origin                     object
# Dest                       object
# date               datetime64[ns]
# time                      float64
# dtype: object

# %%
result.shape
# Out:
# (936842, 36)

# %%
f16.shape
# Out:
# (936961, 21)

# %%
result.count()
# Out:
# Unnamed: 0_x       938399
# FlightDate         938399
# Quarter            938399
# Year               938399
# Month              938399
# DayofMonth         938399
# DepTime            938399
# DepDel15           938399
# CRSDepTime         938399
# DepDelayMinutes    938399
# OriginAirportID    938399
# DestAirportID      938399
# ArrTime            938399
# CRSArrTime         938399
# ArrDel15           936397
# ArrDelayMinutes    936397
# Origin             938399
# Dest               938399
# date               938399
# time               938399
# Unnamed: 0_y       938399
# windspeedKmph      938399
# weatherCode        938399
# precipMM           938399
# WindGustKmph       938399
# pressure           938399
# cloudcover         938399
# winddirDegree      938399
# humidity           938399
# cloudcover.1       938399
# DewPointF          938399
# tempF              938399
# WindChillF         938399
# dtype: int64

# %%
f16.count()
# Out:
# Unnamed: 0         948819
# FlightDate         948819
# Quarter            948819
# Year               948819
# Month              948819
# DayofMonth         948819
# DepTime            939523
# DepDel15           939523
# CRSDepTime         948819
# DepDelayMinutes    939523
# OriginAirportID    948819
# DestAirportID      948819
# ArrTime            938965
# CRSArrTime         948819
# ArrDel15           936961
# ArrDelayMinutes    936961
# Origin             948819
# Dest               948819
# date               948819
# time               938965
# dtype: int64

# %%
result2=pd.merge(result,w16, left_on=['Origin','date','Deptime1'], right_on=['place','date','time'])

# %%
result2
# Out:
#         Unnamed: 0_x FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0                 57 2016-01-01        1  2016      1           1    741.0
# 1               2601 2016-01-01        1  2016      1           1   1043.0
# 2             221649 2016-01-01        1  2016      1           1   1420.0
# 3             356859 2016-01-01        1  2016      1           1   1350.0
# 4             356553 2016-01-01        1  2016      1           1    802.0
# 5              25173 2016-01-01        1  2016      1           1   1011.0
# 6             356910 2016-01-01        1  2016      1           1   1025.0
# 7             356547 2016-01-01        1  2016      1           1    820.0
# 8             226938 2016-01-01        1  2016      1           1   1216.0
# 9                887 2016-01-01        1  2016      1           1   1408.0
# 10             84960 2016-01-01        1  2016      1           1   1445.0
# ...

# %%
f16.shape
# Out:
# (936961, 21)

# %%
result2.shape
# Out:
# (936842, 51)

# %%
result2.to_csv('result16.csv')

# %%
f16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936961 entries, 0 to 948818
# Data columns (total 21 columns):
# Unnamed: 0         936961 non-null int64
# FlightDate         936961 non-null datetime64[ns]
# Quarter            936961 non-null int64
# Year               936961 non-null int64
# Month              936961 non-null int64
# DayofMonth         936961 non-null int64
# DepTime            936961 non-null float64
# DepDel15           936961 non-null float64
# CRSDepTime         936961 non-null int64
# DepDelayMinutes    936961 non-null float64
# OriginAirportID    936961 non-null int64
# DestAirportID      936961 non-null int64
# ArrTime            936961 non-null float64
# CRSArrTime         936961 non-null int64
# ArrDel15           936961 non-null float64
# ArrDelayMinutes    936961 non-null float64
# Origin             936961 non-null object
# Dest               936961 non-null object
# date               936961 non-null datetime64[ns]
# ...

# %%
f17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928477 entries, 0 to 928476
# Data columns (total 21 columns):
# Unnamed: 0         928477 non-null int64
# FlightDate         928477 non-null datetime64[ns]
# Quarter            928477 non-null int64
# Year               928477 non-null int64
# Month              928477 non-null int64
# DayofMonth         928477 non-null int64
# DepTime            916793 non-null float64
# DepDel15           916786 non-null float64
# CRSDepTime         928477 non-null int64
# DepDelayMinutes    916786 non-null float64
# OriginAirportID    928477 non-null int64
# DestAirportID      928477 non-null int64
# ArrTime            916251 non-null float64
# CRSArrTime         928477 non-null int64
# ArrDel15           914475 non-null float64
# ArrDelayMinutes    914475 non-null float64
# Origin             928477 non-null object
# Dest               928477 non-null object
# date               928477 non-null datetime64[ns]
# ...

# %%
frames=[f16,f17]
f67=pd.concat(frames,axis=0)

# %%
print(f16.shape)
# Out:
# (936961, 21)

# %%
f67.shape
# Out:
# (1851436, 21)

# %%
f16.shape
# Out:
# (936961, 21)

# %%
f17.dropna()
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 0                0 2017-01-17        1  2017      1          17   1616.0
# 1                1 2017-01-18        1  2017      1          18   1614.0
# 2                2 2017-01-19        1  2017      1          19   1611.0
# 3                3 2017-01-20        1  2017      1          20   1656.0
# 4                4 2017-01-21        1  2017      1          21   1632.0
# 5                5 2017-01-22        1  2017      1          22   1636.0
# 6                6 2017-01-23        1  2017      1          23   1616.0
# 7                7 2017-01-24        1  2017      1          24   1619.0
# 8                8 2017-01-25        1  2017      1          25   1616.0
# 9                9 2017-01-26        1  2017      1          26   1618.0
# 10              10 2017-01-27        1  2017      1          27   1613.0
# 11              11 2017-01-28        1  2017      1          28   1614.0
# ...

# %%
f17.shape
# Out:
# (928477, 21)

# %%
w16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131760 entries, 0 to 131759
# Data columns (total 16 columns):
# Unnamed: 0       131760 non-null int64
# windspeedKmph    131760 non-null int64
# weatherCode      131760 non-null int64
# precipMM         131760 non-null float64
# WindGustKmph     131760 non-null int64
# pressure         131760 non-null int64
# cloudcover       131760 non-null int64
# winddirDegree    131760 non-null int64
# humidity         131760 non-null int64
# cloudcover.1     131760 non-null int64
# DewPointF        131760 non-null int64
# tempF            131760 non-null int64
# time             131760 non-null int64
# WindChillF       131760 non-null int64
# date             131760 non-null object
# place            131760 non-null object
# dtypes: float64(1), int64(13), object(2)
# memory usage: 16.1+ MB

# %%
w17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131400 entries, 0 to 131399
# Data columns (total 16 columns):
# Unnamed: 0       131400 non-null int64
# windspeedKmph    131400 non-null int64
# weatherCode      131400 non-null int64
# precipMM         131400 non-null float64
# WindGustKmph     131400 non-null int64
# pressure         131400 non-null int64
# cloudcover       131400 non-null int64
# winddirDegree    131400 non-null int64
# humidity         131400 non-null int64
# cloudcover.1     131400 non-null int64
# DewPointF        131400 non-null int64
# tempF            131400 non-null int64
# time             131400 non-null int64
# WindChillF       131400 non-null int64
# date             131400 non-null object
# place            131400 non-null object
# dtypes: float64(1), int64(13), object(2)
# memory usage: 16.0+ MB

# %%
frames=[w16,w17]
w67=pd.concat(frames,axis=0)

# %%
w67.date=pd.to_datetime(w67.date)
w67.dtypes
# Out:
# Unnamed: 0                int64
# windspeedKmph             int64
# weatherCode               int64
# precipMM                float64
# WindGustKmph              int64
# pressure                  int64
# cloudcover                int64
# winddirDegree             int64
# humidity                  int64
# cloudcover.1              int64
# DewPointF                 int64
# tempF                     int64
# time                      int64
# WindChillF                int64
# date             datetime64[ns]
# place                    object
# dtype: object

# %%
w67.shape
# Out:
# (263160, 16)

# %%
result2=pd.merge(result,w67, left_on=['Origin','date','Deptime1'], right_on=['place','date','time'])

# %%
result2.shape
# Out:
# (1851334, 51)

# %%
result=pd.merge(f67,w67, left_on=['Dest','date','Arrtime1'], right_on=['place','date','time'])

# %%
result.shape
# Out:
# (1851334, 36)

# %%
result2.to_csv("mergedfinal.csv")

# %%
f67.shape
# Out:
# (1851436, 21)

# %%
f67.loc[f67['ArrDelayMinutes']>1000]
# Out:
#         Unnamed: 0 FlightDate  Quarter  Year  Month  DayofMonth  DepTime  \
# 5599         13125 2016-01-26        1  2016      1          26   1251.0
# 14124        37877 2016-01-03        1  2016      1           3     14.0
# 35202       154743 2016-01-02        1  2016      1           2   1228.0
# 85987        27920 2016-10-20        4  2016     10          20   1949.0
# 86134        28908 2016-10-14        4  2016     10          14   1358.0
# 89481        40205 2016-10-10        4  2016     10          10    724.0
# 89734        41195 2016-10-27        4  2016     10          27    728.0
# 97530        70191 2016-10-02        4  2016     10           2    906.0
# 99532        77553 2016-10-10        4  2016     10          10   1049.0
# 147290      451685 2016-10-13        4  2016     10          13   1243.0
# 168077      116203 2016-11-18        4  2016     11          18   1423.0
# 195355      250311 2016-11-14        4  2016     11          14   2248.0
# ...

# %%
import matplotlib.pyplot as plt

  
# heights of bars 
height = [1463295,388039] 
  
# labels for bars 
tick_label = ['Not Delayed', 'Delayed'] 
  
# plotting a bar chart 
plt.bar(left, height, tick_label = tick_label, 
        width = 0.1, color = ['red', 'green']) 
  
# naming the x-axis 
 
# naming the y-axis 
plt.ylabel('no of records') 
# plot title 
plt.title('') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 
  
# defining labels 
activities = ['Not Delayed', 'Delayed'] 
  
# portion covered by each label 
slices = [1463295,388039] 
  
# color for each label 
colors = ['g','b'] 
  
# plotting the pie chart 
plt.pie(slices, labels = activities, colors=colors,  
        startangle=90, shadow = True, explode = (0, 0), 
        radius = 1.2, autopct = '%1.1f%%') 
  
# plotting legend 
plt.legend() 
  
# showing the plot 
plt.show()
